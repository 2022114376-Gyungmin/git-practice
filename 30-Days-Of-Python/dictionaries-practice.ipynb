# %% [markdown]
# # Exercises: Day 8

# %%
dog = {}
print(dog)
# Out:
# {}

# %%
dog['name'] = 'Rudi'
dog['color'] = 'white'
dog['breed'] = 'Pomeranian'
dog['legs'] = 4
dog['age'] = 2

print(dog)
# Out:
# {'name': 'Rudi', 'color': 'white', 'breed': 'Pomeranian', 'legs': 4, 'age': 2}

# %%
student = {'first_name': 'Gyeongmin', 'last_name': 'Choi', 'gender': 'Female', 'age': 25, 'marital_status': 'single', 'skills': ['Python', 'AutoCAD'], 'country': 'Korea', 'city': 'Seoul', 'address': 'Seoul, Korea'}

print(student)
# Out:
# {'first_name': 'Gyeongmin', 'last_name': 'Choi', 'gender': 'Female', 'age': 25, 'marital_status': 'single', 'skills': ['Python', 'AutoCAD'], 'country': 'Korea', 'city': 'Seoul', 'address': 'Seoul, Korea'}

# %%
print(len(student))
# Out:
# 9

# %%
print(student['skills'])
print(type(student['skills']))
# Out:
# ['Python', 'AutoCAD']
# <class 'list'>

# %%
student['skills'].append('PG-Steamer')
student['skills'].append('R-Studio')

print(student['skills'])
# Out:
# ['Python', 'AutoCAD', 'PG-Steamer', 'R-Studio']

# %%
student_keys = list(student.keys())
print(student_keys)
# Out:
# ['first_name', 'last_name', 'gender', 'age', 'marital_status', 'skills', 'country', 'city', 'address']

# %%
student_values = list(student.values())
print(student_values)
# Out:
# ['Gyeongmin', 'Choi', 'Female', 25, 'single', ['Python', 'AutoCAD', 'PG-Steamer', 'R-Studio'], 'Korea', 'Seoul', 'Seoul, Korea']

# %%
student_items = list(student.items())
print(student_items)
# Out:
# [('first_name', 'Gyeongmin'), ('last_name', 'Choi'), ('gender', 'Female'), ('age', 25), ('marital_status', 'single'), ('skills', ['Python', 'AutoCAD', 'PG-Steamer', 'R-Studio']), ('country', 'Korea'), ('city', 'Seoul'), ('address', 'Seoul, Korea')]

# %%
student.pop('city')
print(student)
# Out:
# {'first_name': 'Gyeongmin', 'last_name': 'Choi', 'gender': 'Female', 'age': 25, 'marital_status': 'single', 'skills': ['Python', 'AutoCAD', 'PG-Steamer', 'R-Studio'], 'country': 'Korea', 'address': 'Seoul, Korea'}

# %%
del student
