# %% [markdown]
# # Exercises: Day 6

# %% [markdown]
# ## Exercises: Level 1

# %%
empty_tuple = ()
print(empty_tuple)
# Out:
# ()

# %%
sisters = ('Yushin', 'Yujin')
brothers = ('Gyungun', 'Gyungil')

# %%
siblings = brothers + sisters
print(siblings)
# Out:
# ('Gyungun', 'Gyungil', 'Yushin', 'Yujin')

# %%
print(len(siblings))
# Out:
# 4

# %%
family_members = siblings + ('Hyunjung', 'jungju')
print(family_members)
# Out:
# ('Gyungun', 'Gyungil', 'Yushin', 'Yujin', 'Hyunjung', 'jungju')

# %% [markdown]
# # Exercises: Level 2

# %%
only_siblings = family_members[:len(siblings)]
parents = family_members[len(siblings):]

print(only_siblings)
print(parents)
# Out:
# ('Gyungun', 'Gyungil', 'Yushin', 'Yujin')
# ('Hyunjung', 'jungju')

# %%
fruits = ('apple', 'banana', 'orange')
vegetables = ('carrot', 'potato', 'onion')
animal_products = ('milk', 'egg', 'beef')

food_stuff_tp = fruits + vegetables + animal_products

print(food_stuff_tp)
# Out:
# ('apple', 'banana', 'orange', 'carrot', 'potato', 'onion', 'milk', 'egg', 'beef')

# %%
food_stuff_lt = list(food_stuff_tp)

print(food_stuff_lt)
# Out:
# ['apple', 'banana', 'orange', 'carrot', 'potato', 'onion', 'milk', 'egg', 'beef']

# %%
middle_item = food_stuff_tp[len(food_stuff_tp) // 2]

print(middle_item)
# Out:
# potato

# %%
first_three = food_stuff_lt[:3]
last_three = food_stuff_lt[-3:]

print(first_three)
print(last_three)
# Out:
# ['apple', 'banana', 'orange']
# ['milk', 'egg', 'beef']

# %%
del food_stuff_tp

print(food_stuff_tp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 del food_stuff_tp
# ----> 3 print(food_stuff_tp)
#
# NameError: name 'food_stuff_tp' is not defined

# %%
nordic_countries = ('Denmark', 'Finland','Iceland', 'Norway', 'Sweden')

print('Estonia' in nordic_countries)
print('Iceland' in nordic_countries)
# Out:
# False
# True
